# %% [markdown]
# ### Conectando com o MongoDB e Carregando os Dados

# %%
import pandas as pd
from pymongo import MongoClient
from datetime import datetime

#Conectando no MongoDB - Sataging
client = MongoClient('mongodb://localhost:27017/')
db = client['IndustrialDataLake']
collection = db['MachineSensorData']

#Carregando os dados
df = pd.read_csv('dados/manufacturing_6G_dataset.csv')

#Criando um dicionário e convertendo nesse formato para inserir os dados no MongoDB
data = df.to_dict('records')
collection.insert_many(data)

print(f"Dados inseridos com sucesso! Total: {collection.count_documents({})} registros.")
# Out:
# Dados inseridos com sucesso! Total: 300000 registros.

# %% [markdown]
# ### Criação das colunas do DW - SQL Server

# %%
import pyodbc
import pandas as pd
from pymongo import MongoClient
from datetime import datetime

#Configurando a conexão
SQL_SERVER = 'DESKTOP-U623P07'  
SQL_DATABASE = 'FactoryRepair'


#Realizando a conexão com o SQL Server
def create_sql_connection():
    conn_str = f'DRIVER={{ODBC Driver 17 for SQL Server}};SERVER={SQL_SERVER};DATABASE={SQL_DATABASE};trusted_connection=yes;'
    return pyodbc.connect(conn_str)

#Criando a função para criar as tabelas no - DW SQL Server
def create_dw_tables():
    try:
        conn = create_sql_connection()
        cursor = conn.cursor()
        
        #Criando a tabela DimMachine 
        cursor.execute("""
        IF NOT EXISTS (SELECT * FROM sys.tables WHERE name = 'DimMachine')
        CREATE TABLE DimMachine (
            MachineKey INT IDENTITY(1,1) PRIMARY KEY,
            MachineID INT NOT NULL,
            LoadDate DATETIME DEFAULT GETDATE(),
            CONSTRAINT UQ_MachineID UNIQUE (MachineID)
        );
        """)
        
        #Criando a tabela DimTime 
        cursor.execute("""
        IF NOT EXISTS (SELECT * FROM sys.tables WHERE name = 'DimTime')
        CREATE TABLE DimTime (
            TimeKey INT IDENTITY(1,1) PRIMARY KEY,
            Timestamp DATETIME NOT NULL,
            Hour INT,
            Minute INT,
            LoadDate DATETIME DEFAULT GETDATE(),
            CONSTRAINT UQ_Timestamp UNIQUE (Timestamp)
        );
        """)
        
        #Criando a tabela FactProduction 
        cursor.execute("""
        IF NOT EXISTS (SELECT * FROM sys.tables WHERE name = 'FactProduction')
        CREATE TABLE FactProduction (
            ProductionKey INT IDENTITY(1,1) PRIMARY KEY,
            MachineKey INT NOT NULL FOREIGN KEY REFERENCES DimMachine(MachineKey),
            TimeKey INT NOT NULL FOREIGN KEY REFERENCES DimTime(TimeKey),
            Temperature_C FLOAT,
            Vibration_Hz FLOAT,
            Power_Consumption_kW FLOAT,
            Production_Speed_units_per_hr FLOAT,
            Error_Rate_Percent FLOAT,
            Efficiency_Status VARCHAR(10),
            Operation_Mode VARCHAR(20),
            LoadDate DATETIME DEFAULT GETDATE(),
            CONSTRAINT UQ_MachineTime UNIQUE (MachineKey, TimeKey)
        );
        """)
        
        #Criando a tabela FactQuality 
        cursor.execute("""
        IF NOT EXISTS (SELECT * FROM sys.tables WHERE name = 'FactQuality')
        CREATE TABLE FactQuality (
            QualityKey INT IDENTITY(1,1) PRIMARY KEY,
            MachineKey INT NOT NULL FOREIGN KEY REFERENCES DimMachine(MachineKey),
            TimeKey INT NOT NULL FOREIGN KEY REFERENCES DimTime(TimeKey),
            Quality_Control_Defect_Rate_Percent FLOAT,
            Network_Latency_ms FLOAT,
            Packet_Loss_Percent FLOAT,
            Predictive_Maintenance_Score FLOAT,
            LoadDate DATETIME DEFAULT GETDATE(),
            CONSTRAINT UQ_MachineTimeQuality UNIQUE (MachineKey, TimeKey)
        );
        """)
        
        conn.commit()
        print("Tabelas criadas com sucesso no Data Warehouse!")
        
    except Exception as e:
        print(f"Erro ao criar tabelas: {str(e)}")
    finally:
        if 'conn' in locals():
            conn.close()

#Executando a função de criação das tabelas acima
create_dw_tables()
# Out:
# Tabelas criadas com sucesso no Data Warehouse!

# %% [markdown]
# ### Pipeline de ETL

# %%
import pyodbc
import pandas as pd
from pymongo import MongoClient
from datetime import datetime
import time

#Conectando novamente ao SQL Server
SQL_SERVER = 'DESKTOP-U623P07'  
SQL_DATABASE = 'FactoryRepair'

#Criando uma função para criar a conexão com tratamento de erros
def create_sql_connection(max_retries=3, retry_delay=5):
    conn_str = f'DRIVER={{ODBC Driver 17 for SQL Server}};SERVER={SQL_SERVER};DATABASE={SQL_DATABASE};trusted_connection=yes;'
    
    for attempt in range(max_retries):
        try:
            conn = pyodbc.connect(conn_str, timeout=30)
            print("Conexão com SQL Server estabelecida com sucesso!")
            return conn
        except pyodbc.Error as e:
            print(f"Tentativa {attempt + 1} de {max_retries} - Erro ao conectar ao SQL Server: {str(e)}")
            if attempt < max_retries - 1:
                print(f"Aguardando {retry_delay} segundos antes de tentar novamente...")
                time.sleep(retry_delay)
    
    raise Exception("Não foi possível estabelecer conexão com o SQL Server após várias tentativas")

def load_to_sql_dw(df):
    conn = None
    cursor = None
    
    try:
        #Estabelecendo a conexão
        conn = create_sql_connection()
        cursor = conn.cursor()
        
        print("Iniciando processo de carga no Data Warehouse...")
        
        #Convertendo os tipos de dados do DataFrame
        print("Convertendo tipos de dados...")
        df['Machine_ID'] = df['Machine_ID'].astype(int)  # Converter para int nativo do Python
        df['Timestamp'] = pd.to_datetime(df['Timestamp'])
        
        #Carregando a dimensão Máquina 
        print("Carregando dimensão Máquina...")
        machines = df[['Machine_ID']].drop_duplicates()
        machine_keys = {}
        
        for _, row in machines.iterrows():
            try:
                machine_id = int(row['Machine_ID'])  
                
                #Verificando se a máquina já existe
                cursor.execute("SELECT MachineKey FROM DimMachine WHERE MachineID = ?", machine_id)
                result = cursor.fetchone()
                
                if result:
                    machine_keys[machine_id] = result[0]
                else:
                    #Inserindo a nova máquina
                    cursor.execute("""
                    INSERT INTO DimMachine (MachineID) OUTPUT INSERTED.MachineKey VALUES (?)
                    """, machine_id)
                    machine_keys[machine_id] = cursor.fetchone()[0]
                    
            except Exception as e:
                print(f"Erro ao processar máquina ID {row['Machine_ID']}: {str(e)}")
                continue
        
        conn.commit()
        print(f"Dimensão Máquina carregada. Total: {len(machine_keys)} máquinas.")
        
        #Carregando a dimensão Tempo
        print("Carregando dimensão Tempo...")
        times = df[['Timestamp']].drop_duplicates()
        time_keys = {}
        
        for _, row in times.iterrows():
            try:
                timestamp = row['Timestamp'].to_pydatetime()  #Convertendo para datetime 
                hour = timestamp.hour
                minute = timestamp.minute
                
                #Verificando se o timestamp já existe
                cursor.execute("SELECT TimeKey FROM DimTime WHERE Timestamp = ?", timestamp)
                result = cursor.fetchone()
                
                if result:
                    time_keys[timestamp] = result[0]
                else:
                    #Inserindo o novo registro de tempo
                    cursor.execute("""
                    INSERT INTO DimTime (Timestamp, Hour, Minute) 
                    OUTPUT INSERTED.TimeKey 
                    VALUES (?, ?, ?)
                    """, timestamp, hour, minute)
                    time_keys[timestamp] = cursor.fetchone()[0]
                    
            except Exception as e:
                print(f"Erro ao processar timestamp {row['Timestamp']}: {str(e)}")
                continue
        
        conn.commit()
        print(f"Dimensão Tempo carregada. Total: {len(time_keys)} registros temporais.")
        
        #Carregando a fato Produção em lotes 
        print("Carregando fato Produção...")
        batch_size = 1000
        total_rows = len(df)
        inserted_rows = 0
        
        for i in range(0, total_rows, batch_size):
            batch = df.iloc[i:i + batch_size]
            batch_values = []
            
            for _, row in batch.iterrows():
                try:
                    machine_id = int(row['Machine_ID'])
                    timestamp = row['Timestamp'].to_pydatetime()
                    
                    machine_key = machine_keys.get(machine_id)
                    time_key = time_keys.get(timestamp)
                    
                    if machine_key is None or time_key is None:
                        continue
                    
                    #Convertendo todos os valores 
                    batch_values.append((
                        int(machine_key),
                        int(time_key),
                        float(row['Temperature_C']),
                        float(row['Vibration_Hz']),
                        float(row['Power_Consumption_kW']),
                        float(row['Production_Speed_units_per_hr']),
                        float(row['Error_Rate_%']),
                        str(row['Efficiency_Status']),
                        str(row['Operation_Mode'])
                    ))
                except Exception as e:
                    print(f"Erro ao preparar linha {i}: {str(e)}")
                    continue
            
            if batch_values:
                try:
                    cursor.executemany("""
                    INSERT INTO FactProduction (
                        MachineKey, TimeKey, Temperature_C, Vibration_Hz, 
                        Power_Consumption_kW, Production_Speed_units_per_hr, 
                        Error_Rate_Percent, Efficiency_Status, Operation_Mode
                    ) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
                    """, batch_values)
                    inserted_rows += len(batch_values)
                    conn.commit()
                except Exception as e:
                    conn.rollback()
                    print(f"Erro ao inserir lote {i//batch_size}: {str(e)}")
        
        print(f"Fato Produção carregado. Total: {inserted_rows} registros inseridos.")
        
        #Carregando a fato Qualidade em lotes 
        print("Carregando fato Qualidade...")
        inserted_rows = 0
        
        for i in range(0, total_rows, batch_size):
            batch = df.iloc[i:i + batch_size]
            batch_values = []
            
            for _, row in batch.iterrows():
                try:
                    machine_id = int(row['Machine_ID'])
                    timestamp = row['Timestamp'].to_pydatetime()
                    
                    machine_key = machine_keys.get(machine_id)
                    time_key = time_keys.get(timestamp)
                    
                    if machine_key is None or time_key is None:
                        continue
                    
                    #Convertendo todos os valores
                    batch_values.append((
                        int(machine_key),
                        int(time_key),
                        float(row['Quality_Control_Defect_Rate_%']),
                        float(row['Network_Latency_ms']),
                        float(row['Packet_Loss_%']),
                        float(row['Predictive_Maintenance_Score'])
                    ))
                except Exception as e:
                    print(f"Erro ao preparar linha {i}: {str(e)}")
                    continue
            
            if batch_values:
                try:
                    cursor.executemany("""
                    INSERT INTO FactQuality (
                        MachineKey, TimeKey, Quality_Control_Defect_Rate_Percent,
                        Network_Latency_ms, Packet_Loss_Percent, Predictive_Maintenance_Score
                    ) VALUES (?, ?, ?, ?, ?, ?)
                    """, batch_values)
                    inserted_rows += len(batch_values)
                    conn.commit()
                except Exception as e:
                    conn.rollback()
                    print(f"Erro ao inserir lote {i//batch_size}: {str(e)}")
        
        print(f"Fato Qualidade carregado. Total: {inserted_rows} registros inseridos.")
        
        print("Carga no Data Warehouse concluída com sucesso!")
        
    except Exception as e:
        if conn:
            conn.rollback()
        print(f"Erro fatal durante a carga: {str(e)}")
        raise
    finally:
        if cursor:
            cursor.close()
        if conn:
            conn.close()


def run_etl_pipeline():
    print("\n=== Iniciando pipeline ETL melhorado ===")
    
    try:
        #Extração dos dados
        print("\n[ETAPA 1] Extração dos dados do MongoDB")
        client = MongoClient('mongodb://localhost:27017/', serverSelectionTimeoutMS=5000)
        db = client['IndustrialDataLake']
        collection = db['MachineSensorData']
        
        #Testando a conexão com o MongoDB
        client.server_info()
        
        #Extraindo do MongoDB
        print("Executando query no MongoDB...")
        data = list(collection.find({}, {'_id': 0}))
        
        if not data:
            raise Exception("Nenhum dado encontrado no MongoDB")
        
        df = pd.DataFrame(data)
        print(f"Extraídos {len(df)} registros do MongoDB")
        
        #Transformando os Dados
        print("\n[ETAPA 2] Transformação dos dados")
        df['Timestamp'] = pd.to_datetime(df['Timestamp'])
        df['Hour'] = df['Timestamp'].dt.hour
        df['Minute'] = df['Timestamp'].dt.minute
        
        #Verificando os dados faltantes
        print("Verificando dados faltantes...")
        missing_data = df.isnull().sum()
        if missing_data.any():
            print("Aviso: Dados faltantes encontrados:")
            print(missing_data[missing_data > 0])
            # Preencher ou remover valores nulos conforme necessário
            df.fillna(0, inplace=True)
        
        #Realizando a carga
        print("\n[ETAPA 3] Carga no SQL Server DW")
        load_to_sql_dw(df)
        
        print("\n=== Pipeline ETL concluído com sucesso! ===")
        
    except Exception as e:
        print(f"\n!!! Falha no pipeline ETL: {str(e)}")
    finally:
        if 'client' in locals():
            client.close()

#Executando todo o pipeline de ETL completo
if __name__ == "__main__":
    run_etl_pipeline()
# Out:
# === Iniciando pipeline ETL melhorado ===
#
# [ETAPA 1] Extração dos dados do MongoDB
# Executando query no MongoDB...
# Extraídos 300000 registros do MongoDB
#
# [ETAPA 2] Transformação dos dados
# Verificando dados faltantes...
#
# [ETAPA 3] Carga no SQL Server DW
# Conexão com SQL Server estabelecida com sucesso!
# Iniciando processo de carga no Data Warehouse...
# Convertendo tipos de dados...
# Carregando dimensão Máquina...
# Dimensão Máquina carregada. Total: 50 máquinas.
# Carregando dimensão Tempo...
# Dimensão Tempo carregada. Total: 100000 registros temporais.
# Carregando fato Produção...
# Erro ao inserir lote 0: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (1, 1). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 1: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (19, 1001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 2: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (13, 2001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 3: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (29, 3001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 4: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (7, 4001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 5: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (44, 5001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 6: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (42, 6001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 7: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (31, 7001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 8: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (44, 8001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 9: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (30, 9001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 10: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (20, 10001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 11: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (26, 11001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 12: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (19, 12001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 13: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (40, 13001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 14: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (36, 14001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 15: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (47, 15001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 16: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (45, 16001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 17: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (31, 17001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 18: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (1, 18001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 19: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (28, 19001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 20: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (30, 20001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 21: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (13, 21001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 22: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (7, 22001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 23: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (30, 23001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 24: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (30, 24001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 25: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (33, 25001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 26: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (33, 26001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 27: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (9, 27001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 28: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (49, 28001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 29: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (44, 29001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 30: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (47, 30001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 31: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (23, 31001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 32: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (39, 32001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 33: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (2, 33001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 34: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (16, 34001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 35: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (39, 35001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 36: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (12, 36001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 37: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (45, 37001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 38: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (5, 38001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 39: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (14, 39001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 40: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (20, 40001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 41: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (36, 41001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 42: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (44, 42001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 43: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (9, 43001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 44: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (25, 44001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 45: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (16, 45001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 46: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (9, 46001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 47: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (7, 47001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 48: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (44, 48001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 49: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (13, 49001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 50: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (38, 50001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 51: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (19, 51001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 52: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (15, 52001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 53: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (50, 53001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 54: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (12, 54001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 55: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (47, 55001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 56: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (49, 56001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 57: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (46, 57001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 58: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (22, 58001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 59: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (10, 59001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 60: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (39, 60001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 61: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (1, 61001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 62: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (31, 62001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 63: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (31, 63001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 64: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (20, 64001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 65: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (40, 65001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 66: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (16, 66001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 67: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (18, 67001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 68: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (7, 68001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 69: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (22, 69001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 70: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (12, 70001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 71: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (17, 71001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 72: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (25, 72001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 73: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (9, 73001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 74: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (39, 74001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 75: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (25, 75001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 76: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (44, 76001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 77: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (30, 77001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 78: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (10, 78001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 79: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (7, 79001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 80: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (25, 80001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 81: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (21, 81001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 82: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (45, 82001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 83: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (32, 83001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 84: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (17, 84001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 85: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (1, 85001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 86: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (43, 86001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 87: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (47, 87001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 88: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (14, 88001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 89: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (25, 89001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 90: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (3, 90001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 91: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (48, 91001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 92: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (13, 92001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 93: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (43, 93001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 94: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (23, 94001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 95: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (29, 95001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 96: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (22, 96001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 97: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (15, 97001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 98: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (43, 98001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 99: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (23, 99001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 100: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (1, 1). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 101: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (19, 1001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 102: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (13, 2001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 103: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (29, 3001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 104: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (7, 4001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 105: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (44, 5001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 106: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (42, 6001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 107: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (31, 7001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 108: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (44, 8001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 109: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (30, 9001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 110: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (20, 10001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 111: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (26, 11001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 112: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (19, 12001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 113: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (40, 13001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 114: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (36, 14001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 115: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (47, 15001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 116: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (45, 16001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 117: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (31, 17001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 118: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (1, 18001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 119: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (28, 19001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 120: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (30, 20001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 121: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTime'. Não é possível inserir a chave duplicada no objeto 'dbo.FactProduction'. O valor de chave duplicada é (13, 21001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# ...
# Erro ao inserir lote 260: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (39, 60001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 261: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (1, 61001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 262: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (31, 62001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 263: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (31, 63001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 264: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (20, 64001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 265: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (40, 65001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 266: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (16, 66001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 267: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (18, 67001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 268: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (7, 68001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 269: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (22, 69001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 270: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (12, 70001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 271: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (17, 71001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 272: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (25, 72001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 273: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (9, 73001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 274: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (39, 74001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 275: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (25, 75001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 276: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (44, 76001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 277: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (30, 77001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 278: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (10, 78001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 279: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (7, 79001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 280: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (25, 80001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 281: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (21, 81001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 282: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (45, 82001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 283: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (32, 83001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 284: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (17, 84001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 285: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (1, 85001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 286: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (43, 86001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 287: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (47, 87001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 288: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (14, 88001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 289: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (25, 89001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 290: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (3, 90001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 291: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (48, 91001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 292: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (13, 92001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 293: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (43, 93001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 294: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (23, 94001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 295: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (29, 95001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 296: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (22, 96001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 297: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (15, 97001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 298: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (43, 98001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Erro ao inserir lote 299: ('23000', "[23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Violação da restrição UNIQUE KEY 'UQ_MachineTimeQuality'. Não é possível inserir a chave duplicada no objeto 'dbo.FactQuality'. O valor de chave duplicada é (23, 99001). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]A instrução foi finalizada. (3621)")
# Fato Qualidade carregado. Total: 0 registros inseridos.
# Carga no Data Warehouse concluída com sucesso!
#
# === Pipeline ETL concluído com sucesso! ===

# %% [markdown]
# ### Querys - Análises SQL

# %% [markdown]
# #### Eficiência por Máquina

# %%
conn = create_sql_connection()
cursor = conn.cursor()

#Executando a consulta
query = '''
SELECT 
    m.MachineID,
    AVG(p.Production_Speed_units_per_hr) AS VelocidadeMediaProducao,
    AVG(p.Error_Rate_Percent) AS TaxaMediaErros,
    p.Efficiency_Status,
    COUNT(*) AS ContagemLeituras
FROM FactProduction p
JOIN DimMachine m ON p.MachineKey = m.MachineKey
GROUP BY m.MachineID, p.Efficiency_Status
ORDER BY VelocidadeMediaProducao DESC;
'''

df = pd.read_sql_query(query, conn)

#Formatando as colunas 
df['VelocidadeMediaProducao'] = df['VelocidadeMediaProducao'].apply(lambda x: f'R${x:,.2f}')
df['TaxaMediaErros'] = df['TaxaMediaErros'].apply(lambda x: f'{x:,.2f}%')

print(df)
# Out:
# Conexão com SQL Server estabelecida com sucesso!
#      MachineID VelocidadeMediaProducao TaxaMediaErros Efficiency_Status  \
# 0            4                R$458.86          1.13%              High
# 1           34                R$458.67          1.00%              High
# 2           10                R$457.31          1.08%              High
# 3           32                R$455.88          1.06%              High
# 4           47                R$455.70          1.08%              High
# ..         ...                     ...            ...               ...
# 145         40                R$250.17          9.03%               Low
# 146         17                R$250.13          8.89%               Low
# 147         38                R$249.99          9.08%               Low
# 148         46                R$249.20          8.73%               Low
# 149          5                R$248.55          8.88%               Low
#
#      ContagemLeituras
# 0                  51
# 1                  60
# 2                  63
# 3                  49
# 4                  48
# ..                ...
# 145              1572
# 146              1617
# 147              1601
# 148              1498
# 149              1589
#
# [150 rows x 5 columns]
# C:\Users\Matt\AppData\Local\Temp\ipykernel_14568\2172867650.py:18: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %% [markdown]
# #### OEE Eficácia Geral do Equipamento

# %%
query = '''
SELECT 
    m.MachineID,
    AVG(p.Production_Speed_units_per_hr) / MAX(p.Production_Speed_units_per_hr) AS Disponibilidade,
    1 - AVG(q.Quality_Control_Defect_Rate_Percent / 100) AS Qualidade,
    (AVG(p.Production_Speed_units_per_hr) / MAX(p.Production_Speed_units_per_hr)) * 
    (1 - AVG(q.Quality_Control_Defect_Rate_Percent / 100)) AS OEE
FROM FactProduction p
JOIN FactQuality q ON p.MachineKey = q.MachineKey AND p.TimeKey = q.TimeKey
JOIN DimMachine m ON p.MachineKey = m.MachineKey
GROUP BY m.MachineID
ORDER BY OEE DESC;
'''

df = pd.read_sql_query(query, conn)

#Formatando as colunas 
df['Disponibilidade'] = df['Disponibilidade'].apply(lambda x: f'{x:,.2f}')
df['Qualidade'] = df['Qualidade'].apply(lambda x: f'{x*100:,.2f}%')
df['OEE'] = df['OEE'].apply(lambda x: f'{x:,.2f}')

print(df)
# Out:
#     MachineID Disponibilidade Qualidade   OEE
# 0          27            0.57    95.11%  0.54
# 1          16            0.57    94.98%  0.54
# 2          31            0.56    94.92%  0.54
# 3          23            0.56    94.99%  0.53
# 4          15            0.56    94.83%  0.53
# 5          39            0.56    94.93%  0.53
# 6          43            0.56    95.01%  0.53
# 7          26            0.56    95.06%  0.53
# 8           3            0.56    94.95%  0.53
# 9          24            0.56    95.01%  0.53
# 10         34            0.56    94.94%  0.53
# 11         44            0.56    95.02%  0.53
# 12          1            0.56    94.96%  0.53
# 13         22            0.56    94.90%  0.53
# 14         32            0.56    95.01%  0.53
# 15         37            0.55    95.11%  0.53
# 16         41            0.55    95.06%  0.53
# 17         45            0.55    95.16%  0.53
# 18         19            0.55    95.03%  0.53
# 19         20            0.55    94.97%  0.53
# 20         10            0.55    95.09%  0.52
# 21         30            0.55    95.05%  0.52
# 22          8            0.55    94.93%  0.52
# 23         50            0.55    95.04%  0.52
# 24         18            0.55    94.95%  0.52
# 25         42            0.55    94.95%  0.52
# 26         47            0.55    94.91%  0.52
# 27         48            0.55    95.09%  0.52
# 28         11            0.55    94.91%  0.52
# 29         21            0.55    95.04%  0.52
# 30         33            0.55    94.95%  0.52
# 31          2            0.55    94.99%  0.52
# 32         28            0.55    95.05%  0.52
# 33          7            0.55    94.96%  0.52
# 34         12            0.55    94.98%  0.52
# 35         35            0.55    95.02%  0.52
# 36         29            0.55    95.10%  0.52
# 37          4            0.55    94.97%  0.52
# 38         13            0.55    95.00%  0.52
# 39         36            0.55    94.93%  0.52
# 40          6            0.55    95.02%  0.52
# 41         25            0.55    94.98%  0.52
# 42          5            0.55    95.05%  0.52
# 43         49            0.55    94.98%  0.52
# 44          9            0.54    94.85%  0.52
# 45         14            0.54    94.89%  0.52
# 46         38            0.54    94.94%  0.52
# 47         40            0.54    94.99%  0.52
# 48         17            0.54    94.97%  0.51
# 49         46            0.54    95.00%  0.51
# C:\Users\Matt\AppData\Local\Temp\ipykernel_14568\2113942319.py:15: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %% [markdown]
# ### Análise de Temperatura vs Defeitos

# %%
query = '''
WITH TempRanges AS (
    SELECT
        m.MachineID,
        CASE
            WHEN p.Temperature_C < 50 THEN 'Baixa (<50)'
            WHEN p.Temperature_C BETWEEN 50 AND 70 THEN 'Normal (50-70)'
            WHEN p.Temperature_C BETWEEN 70 AND 85 THEN 'Alta (70-85)'
            ELSE 'Muito Alta (>85)'
        END AS FaixaTemperatura,
        q.Quality_Control_Defect_Rate_Percent AS DefectRate
    FROM FactProduction p
    JOIN FactQuality q ON p.MachineKey = q.MachineKey AND p.TimeKey = q.TimeKey
    JOIN DimMachine m ON p.MachineKey = m.MachineKey
    JOIN DimTime t ON p.TimeKey = t.TimeKey
)
SELECT
    FaixaTemperatura,
    AVG(DefectRate) AS TaxaDefeitoMedia,
    COUNT(*) AS TotalRegistros
FROM TempRanges
GROUP BY FaixaTemperatura
ORDER BY TaxaDefeitoMedia DESC;
'''

df = pd.read_sql_query(query, conn)

#Formatando as colunas 
df['TaxaDefeitoMedia'] = df['TaxaDefeitoMedia'].apply(lambda x: f'{x:,.2f}%')

print(df)
# Out:
# C:\Users\Matt\AppData\Local\Temp\ipykernel_14568\2021189252.py:26: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)
#    FaixaTemperatura TaxaDefeitoMedia  TotalRegistros
# 0    Normal (50-70)            5.02%           33518
# 1       Baixa (<50)            5.01%           33198
# 2      Alta (70-85)            5.01%           24814
# 3  Muito Alta (>85)            4.97%            8470

# %% [markdown]
# ### Análise de Desempenho por Turno / Horário

# %%
#Configurando a conexão no SQL Novamente
SQL_SERVER = 'DESKTOP-U623P07' 
SQL_DATABASE = 'FactoryRepair'

#Função para criar conexão com o tratamento caso der erro de conexão
def create_sql_connection(max_retries=3, retry_delay=5):
    conn_str = f'DRIVER={{ODBC Driver 17 for SQL Server}};SERVER={SQL_SERVER};DATABASE={SQL_DATABASE};trusted_connection=yes;'
    
    for attempt in range(max_retries):
        try:
            conn = pyodbc.connect(conn_str, timeout=30)
            print("Conexão com SQL Server estabelecida com sucesso!")
            return conn
        except pyodbc.Error as e:
            print(f"Tentativa {attempt + 1} de {max_retries} - Erro ao conectar ao SQL Server: {str(e)}")
            if attempt < max_retries - 1:
                print(f"Aguardando {retry_delay} segundos antes de tentar novamente...")
                time.sleep(retry_delay)
    
    raise Exception("Não foi possível estabelecer conexão com o SQL Server após várias tentativas")

def load_to_sql_dw(df):
    conn = None
    cursor = None

conn = create_sql_connection()
cursor = conn.cursor()

query = '''
SELECT 
    DATEPART(HOUR, t.Timestamp) AS Hora,
    FORMAT(AVG(p.Production_Speed_units_per_hr), 'N2') AS VelocidadeMediaProducao,
    CONCAT(FORMAT(AVG(p.Error_Rate_Percent), 'N2'), '%') AS TaxaErroMedia,
    COUNT(*) AS TotalRegistros
FROM FactProduction p
JOIN DimTime t ON p.TimeKey = t.TimeKey
GROUP BY DATEPART(HOUR, t.Timestamp)
ORDER BY Hora;
'''

df = pd.read_sql_query(query, conn)

print(df)
# Out:
# Conexão com SQL Server estabelecida com sucesso!
#     Hora VelocidadeMediaProducao TaxaErroMedia  TotalRegistros
# 0      0                  275,51         7,37%            4200
# 1      1                  274,89         7,63%            4200
# 2      2                  278,73         7,50%            4200
# 3      3                  277,80         7,46%            4200
# 4      4                  275,03         7,46%            4200
# 5      5                  274,59         7,47%            4200
# 6      6                  277,93         7,47%            4200
# 7      7                  276,18         7,61%            4200
# 8      8                  276,30         7,39%            4200
# 9      9                  275,23         7,49%            4200
# 10    10                  273,41         7,43%            4180
# 11    11                  273,87         7,28%            4140
# 12    12                  278,19         7,60%            4140
# 13    13                  274,12         7,57%            4140
# 14    14                  276,45         7,54%            4140
# 15    15                  272,97         7,43%            4140
# 16    16                  279,50         7,57%            4140
# 17    17                  280,25         7,60%            4140
# 18    18                  271,27         7,39%            4140
# 19    19                  275,31         7,61%            4140
# 20    20                  273,62         7,55%            4140
# 21    21                  276,26         7,60%            4140
# 22    22                  275,08         7,56%            4140
# 23    23                  279,50         7,54%            4140
# C:\Users\Matt\AppData\Local\Temp\ipykernel_14568\3887636270.py:42: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %% [markdown]
# #### Comparação Entre Máquinas Ativas e Ociosas

# %%
query = '''
SELECT 
    CASE 
        WHEN p.Operation_Mode = 'Active' THEN 'Ativa'
        ELSE 'Ociosa/Manutenção'
    END AS StatusOperacao,
    COUNT(*) AS TotalRegistros,
    FORMAT(AVG(p.Temperature_C), 'N2') AS TemperaturaMedia,
    FORMAT(AVG(p.Vibration_Hz), 'N2') AS VibracaoMedia,
    FORMAT(AVG(p.Power_Consumption_kW), 'N2') AS ConsumoEnergiaMedio
FROM FactProduction p
GROUP BY CASE 
        WHEN p.Operation_Mode = 'Active' THEN 'Ativa'
        ELSE 'Ociosa/Manutenção'
    END;
'''

df = pd.read_sql_query(query, conn)

print(df)
# Out:
#       StatusOperacao  TotalRegistros TemperaturaMedia VibracaoMedia  \
# 0              Ativa           70054            60,06          2,55
# 1  Ociosa/Manutenção           29946            60,00          2,54
#
#   ConsumoEnergiaMedio
# 0                5,75
# 1                5,73
# C:\Users\Matt\AppData\Local\Temp\ipykernel_14568\3683968271.py:18: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %% [markdown]
# #### Máquinas com maior taxa de defeitos

# %%
query = '''
SELECT TOP 10
    m.MachineID,
    CONCAT(FORMAT(AVG(q.Quality_Control_Defect_Rate_Percent), 'N2'), '%') AS TaxaDefeitoMedia,
    COUNT(*) AS TotalRegistros
FROM FactQuality q
JOIN DimMachine m ON q.MachineKey = m.MachineKey
GROUP BY m.MachineID
ORDER BY TaxaDefeitoMedia DESC;
'''

df = pd.read_sql_query(query, conn)

print(df)
# Out:
#    MachineID TaxaDefeitoMedia  TotalRegistros
# 0         15            5,17%            2027
# 1          9            5,15%            1991
# 2         14            5,11%            1941
# 3         22            5,10%            2031
# 4         11            5,09%            1951
# 5         47            5,09%            2001
# 6         31            5,08%            1933
# 7         39            5,07%            1993
# 8          8            5,07%            1967
# 9         36            5,07%            2085
# C:\Users\Matt\AppData\Local\Temp\ipykernel_14568\2288380342.py:12: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %% [markdown]
# #### Correlação entre temperatura e defeitos

# %%
query = '''
WITH TempRanges AS (
    SELECT
        m.MachineID,
        CASE
            WHEN p.Temperature_C < 50 THEN 'Baixa (<50)'
            WHEN p.Temperature_C BETWEEN 50 AND 70 THEN 'Normal (50-70)'
            WHEN p.Temperature_C BETWEEN 70 AND 85 THEN 'Alta (70-85)'
            ELSE 'Muito Alta (>85)'
        END AS FaixaTemperatura,
        q.Quality_Control_Defect_Rate_Percent
    FROM FactProduction p
    JOIN FactQuality q ON p.MachineKey = q.MachineKey AND p.TimeKey = q.TimeKey
    JOIN DimMachine m ON p.MachineKey = m.MachineKey
)
SELECT
    FaixaTemperatura,
    CONCAT(FORMAT(AVG(Quality_Control_Defect_Rate_Percent), 'N2'), '%') AS TaxaDefeitoMedia,
    COUNT(*) AS TotalRegistros
FROM TempRanges
GROUP BY FaixaTemperatura
ORDER BY 
    CASE FaixaTemperatura
        WHEN 'Baixa (<50)' THEN 1
        WHEN 'Normal (50-70)' THEN 2
        WHEN 'Alta (70-85)' THEN 3
        ELSE 4
    END;
'''

df = pd.read_sql_query(query, conn)

print(df)
# Out:
#    FaixaTemperatura TaxaDefeitoMedia  TotalRegistros
# 0       Baixa (<50)            5,01%           33198
# 1    Normal (50-70)            5,02%           33518
# 2      Alta (70-85)            5,01%           24814
# 3  Muito Alta (>85)            4,97%            8470
# C:\Users\Matt\AppData\Local\Temp\ipykernel_14568\2997150497.py:32: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %% [markdown]
# #### Consumo de energia por modo de operação

# %%
query = '''
SELECT
    Operation_Mode AS ModoOperacao,
    FORMAT(AVG(Power_Consumption_kW), 'N2') AS ConsumoMedioEnergia,
    FORMAT(MIN(Power_Consumption_kW), 'N2') AS ConsumoMinimo,
    FORMAT(MAX(Power_Consumption_kW), 'N2') AS ConsumoMaximo,
    COUNT(*) AS TotalRegistros
FROM FactProduction
GROUP BY Operation_Mode
ORDER BY ConsumoMedioEnergia DESC;
'''

df = pd.read_sql_query(query, conn)

print(df)
# Out:
#   ModoOperacao ConsumoMedioEnergia ConsumoMinimo ConsumoMaximo  TotalRegistros
# 0       Active                5,75          1,50         10,00           70054
# 1         Idle                5,73          1,50         10,00           20057
# 2  Maintenance                5,73          1,50         10,00            9889
# C:\Users\Matt\AppData\Local\Temp\ipykernel_14568\260483734.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %% [markdown]
# #### Máquinas Menos Eficientes Energeticamente

# %%
query = '''
SELECT TOP 10
    m.MachineID,
    FORMAT(AVG(p.Power_Consumption_kW / p.Production_Speed_units_per_hr), 'N2') AS ConsumoPorUnidade,
    FORMAT(AVG(p.Power_Consumption_kW), 'N2') AS ConsumoMedioEnergia,
    FORMAT(AVG(p.Production_Speed_units_per_hr), 'N2') AS VelocidadeMediaProducao
FROM FactProduction p
JOIN DimMachine m ON p.MachineKey = m.MachineKey
WHERE p.Operation_Mode = 'Active'
GROUP BY m.MachineID
ORDER BY ConsumoPorUnidade DESC;
'''

df = pd.read_sql_query(query, conn)

print(df)
# Out:
#    MachineID ConsumoPorUnidade ConsumoMedioEnergia VelocidadeMediaProducao
# 0         21              0,03                5,90                  271,96
# 1         26              0,03                5,74                  280,64
# 2         40              0,03                5,76                  271,68
# 3         16              0,03                5,82                  286,25
# 4          4              0,03                5,73                  271,12
# 5         15              0,03                5,81                  281,65
# 6          2              0,03                5,73                  275,21
# 7         11              0,03                5,75                  277,52
# 8          7              0,03                5,69                  274,96
# 9          1              0,03                5,83                  277,77
# C:\Users\Matt\AppData\Local\Temp\ipykernel_14568\3816957555.py:15: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %% [markdown]
# #### Identificar máquinas com vibração anormal

# %%
query = '''
SELECT
    m.MachineID,
    FORMAT(AVG(p.Vibration_Hz), 'N2') AS VibracaoMedia,
    FORMAT(STDEV(p.Vibration_Hz), 'N2') AS DesvioPadraoVibracao,
    FORMAT(MAX(p.Vibration_Hz), 'N2') AS VibracaoMaxima,
    COUNT(*) AS TotalRegistros
FROM FactProduction p
JOIN DimMachine m ON p.MachineKey = m.MachineKey
WHERE p.Operation_Mode = 'Active'
GROUP BY m.MachineID
HAVING AVG(p.Vibration_Hz) > 3.5 OR STDEV(p.Vibration_Hz) > 1.2
ORDER BY VibracaoMedia DESC;
'''

df = pd.read_sql_query(query, conn)


print(df)
# Out:
#     MachineID VibracaoMedia DesvioPadraoVibracao VibracaoMaxima  \
# 0          34          2,66                 1,42           5,00
# 1           3          2,63                 1,43           5,00
# 2          19          2,60                 1,41           4,99
# 3          37          2,60                 1,43           5,00
# 4          26          2,59                 1,43           5,00
# 5          38          2,59                 1,41           4,99
# 6           1          2,58                 1,40           5,00
# 7          15          2,58                 1,41           5,00
# 8          36          2,58                 1,43           4,99
# 9          50          2,57                 1,41           5,00
# 10         23          2,57                 1,42           5,00
# 11          4          2,57                 1,41           4,99
# 12         45          2,57                 1,40           5,00
# 13         47          2,57                 1,42           5,00
# 14         17          2,57                 1,45           5,00
# 15         46          2,57                 1,41           4,99
# 16         33          2,57                 1,41           4,99
# 17         49          2,57                 1,41           4,99
# 18         44          2,57                 1,40           4,99
# 19         14          2,56                 1,44           5,00
# 20         42          2,56                 1,45           5,00
# 21         25          2,56                 1,41           5,00
# 22          7          2,56                 1,41           5,00
# 23          2          2,56                 1,41           5,00
# 24         27          2,55                 1,41           5,00
# 25         16          2,55                 1,41           4,99
# 26         21          2,55                 1,38           5,00
# 27         24          2,55                 1,41           5,00
# 28         20          2,55                 1,42           5,00
# 29         18          2,54                 1,41           5,00
# 30         10          2,54                 1,41           5,00
# 31         43          2,54                 1,39           5,00
# 32          5          2,54                 1,40           4,99
# 33          6          2,54                 1,43           5,00
# 34         31          2,54                 1,42           5,00
# 35         41          2,54                 1,44           5,00
# 36         40          2,54                 1,43           4,99
# 37         11          2,53                 1,38           5,00
# 38         13          2,53                 1,41           5,00
# 39          9          2,53                 1,42           4,99
# 40         35          2,53                 1,41           5,00
# 41         12          2,52                 1,40           5,00
# 42         28          2,52                 1,40           4,99
# 43          8          2,52                 1,44           5,00
# 44         32          2,52                 1,41           5,00
# 45         22          2,51                 1,40           5,00
# 46         39          2,50                 1,43           5,00
# 47         29          2,50                 1,40           5,00
# 48         30          2,49                 1,39           5,00
# 49         48          2,47                 1,38           5,00
#
#     TotalRegistros
# 0             1346
# 1             1369
# 2             1417
# 3             1391
# 4             1429
# 5             1450
# 6             1336
# 7             1430
# 8             1476
# 9             1340
# 10            1487
# 11            1424
# 12            1446
# 13            1389
# 14            1413
# 15            1376
# 16            1340
# 17            1384
# 18            1417
# 19            1335
# 20            1436
# 21            1415
# 22            1373
# 23            1434
# 24            1368
# 25            1427
# 26            1455
# 27            1360
# 28            1365
# 29            1421
# 30            1405
# 31            1331
# 32            1436
# 33            1364
# 34            1357
# 35            1399
# 36            1407
# 37            1362
# 38            1424
# 39            1369
# 40            1355
# 41            1405
# 42            1430
# 43            1370
# 44            1417
# 45            1409
# 46            1364
# 47            1442
# 48            1480
# 49            1479
# C:\Users\Matt\AppData\Local\Temp\ipykernel_14568\3417990692.py:17: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %% [markdown]
# #### Padrões antes de falhas (análise de tendência)

# %%
query = '''
WITH Falhas AS (
    SELECT 
        m.MachineID,
        t.Timestamp,
        p.Error_Rate_Percent,
        LAG(p.Temperature_C, 1) OVER (PARTITION BY m.MachineID ORDER BY t.Timestamp) AS TempAnterior,
        LAG(p.Vibration_Hz, 1) OVER (PARTITION BY m.MachineID ORDER BY t.Timestamp) AS VibAnterior,
        LAG(p.Power_Consumption_kW, 1) OVER (PARTITION BY m.MachineID ORDER BY t.Timestamp) AS PowerAnterior
    FROM FactProduction p
    JOIN DimMachine m ON p.MachineKey = m.MachineKey
    JOIN DimTime t ON p.TimeKey = t.TimeKey
    WHERE p.Error_Rate_Percent > 5  -- Considerando como "falha" quando ErrorRate > 5%
)
SELECT
    MachineID,
    FORMAT(AVG(TempAnterior), 'N2') AS TemperaturaMediaAntesFalha,
    FORMAT(AVG(VibAnterior), 'N2') AS VibracaoMediaAntesFalha,
    FORMAT(AVG(PowerAnterior), 'N2') AS ConsumoEnergiaMedioAntesFalha,
    COUNT(*) AS TotalFalhasAnalisadas
FROM Falhas
GROUP BY MachineID;
'''

df = pd.read_sql_query(query, conn)

print(df)
# Out:
# C:\Users\Matt\AppData\Local\Temp\ipykernel_14568\2184155748.py:26: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)
#     MachineID TemperaturaMediaAntesFalha VibracaoMediaAntesFalha  \
# 0           1                      59,49                    2,57
# 1           3                      59,07                    2,61
# 2          10                      60,31                    2,56
# 3          12                      59,57                    2,50
# 4          17                      60,17                    2,59
# 5          19                      59,72                    2,55
# 6          26                      60,08                    2,63
# 7          28                      59,26                    2,55
# 8          35                      60,27                    2,51
# 9          37                      60,20                    2,55
# 10         42                      60,56                    2,54
# 11         44                      60,16                    2,58
# 12          2                      59,91                    2,55
# 13          4                      59,68                    2,59
# 14          9                      60,66                    2,50
# 15         11                      59,95                    2,53
# 16         18                      59,72                    2,54
# 17         20                      59,89                    2,56
# 18         27                      60,04                    2,58
# 19         29                      60,59                    2,52
# 20         34                      59,48                    2,61
# 21         36                      60,21                    2,55
# 22         43                      59,31                    2,52
# 23         45                      60,23                    2,58
# 24         13                      59,70                    2,54
# 25         14                      59,99                    2,59
# 26         15                      59,46                    2,53
# 27         16                      60,09                    2,53
# 28         30                      59,67                    2,51
# 29         31                      59,93                    2,47
# 30         32                      58,62                    2,52
# 31         33                      60,96                    2,60
# 32         46                      60,41                    2,56
# 33         47                      60,45                    2,54
# 34         48                      60,49                    2,53
# 35         49                      59,83                    2,55
# 36         50                      59,78                    2,54
# 37          5                      60,72                    2,57
# 38          6                      60,12                    2,51
# 39          7                      60,13                    2,55
# 40          8                      60,05                    2,58
# 41         21                      60,04                    2,54
# 42         22                      59,74                    2,57
# 43         23                      60,15                    2,57
# 44         24                      59,86                    2,60
# 45         25                      60,07                    2,54
# 46         38                      60,61                    2,59
# 47         39                      60,23                    2,52
# 48         40                      60,30                    2,58
# 49         41                      59,68                    2,59
#
#    ConsumoEnergiaMedioAntesFalha  TotalFalhasAnalisadas
# 0                           5,86                   1282
# 1                           5,89                   1354
# 2                           5,83                   1334
# 3                           5,71                   1289
# 4                           5,78                   1383
# 5                           5,68                   1322
# 6                           5,85                   1357
# 7                           5,69                   1381
# 8                           5,72                   1272
# 9                           5,69                   1293
# 10                          5,75                   1346
# 11                          5,89                   1370
# 12                          5,74                   1359
# 13                          5,69                   1342
# 14                          5,73                   1339
# 15                          5,74                   1296
# 16                          5,66                   1345
# 17                          5,85                   1290
# 18                          5,69                   1310
# 19                          5,64                   1396
# 20                          5,70                   1308
# 21                          5,71                   1375
# 22                          5,78                   1295
# 23                          5,73                   1370
# 24                          5,60                   1360
# 25                          5,81                   1327
# 26                          5,77                   1339
# 27                          5,81                   1342
# 28                          5,78                   1408
# 29                          5,84                   1323
# 30                          5,71                   1378
# 31                          5,77                   1314
# 32                          5,71                   1243
# 33                          5,73                   1367
# 34                          5,84                   1367
# 35                          5,85                   1283
# 36                          5,80                   1266
# 37                          5,79                   1341
# 38                          5,66                   1294
# 39                          5,69                   1273
# 40                          5,77                   1349
# 41                          5,83                   1347
# 42                          5,73                   1385
# 43                          5,67                   1359
# 44                          5,69                   1290
# 45                          5,71                   1351
# 46                          5,66                   1383
# 47                          5,67                   1328
# 48                          5,74                   1363
# 49                          5,69                   1322

# %% [markdown]
# #### Análise de Eficiência Geral (OEE)

# %%
query = '''
SELECT
    m.MachineID,
    -- Disponibilidade (Tempo Ativo / Tempo Total)
    FORMAT(CAST(SUM(CASE WHEN p.Operation_Mode = 'Active' THEN 1 ELSE 0 END) AS FLOAT) / COUNT(*), 'N2') AS Disponibilidade,
    
    -- Desempenho (Produção Real / Produção Teórica Máxima)
    FORMAT(AVG(p.Production_Speed_units_per_hr) / MAX(p.Production_Speed_units_per_hr), 'N2') AS Desempenho,
    
    -- Qualidade (1 - Taxa de Defeitos)
    FORMAT(1 - AVG(q.Quality_Control_Defect_Rate_Percent / 100), 'N2') AS Qualidade,
    
    -- OEE Total (Disponibilidade × Desempenho × Qualidade)
    FORMAT(
        (CAST(SUM(CASE WHEN p.Operation_Mode = 'Active' THEN 1 ELSE 0 END) AS FLOAT) / COUNT(*)) *
        (AVG(p.Production_Speed_units_per_hr) / MAX(p.Production_Speed_units_per_hr)) *
        (1 - AVG(q.Quality_Control_Defect_Rate_Percent / 100)),
        'N2'
    ) AS OEE,
    
    COUNT(*) AS TotalRegistros
FROM FactProduction p
JOIN FactQuality q ON p.MachineKey = q.MachineKey AND p.TimeKey = q.TimeKey
JOIN DimMachine m ON p.MachineKey = m.MachineKey
GROUP BY m.MachineID
ORDER BY OEE DESC;
'''

df = pd.read_sql_query(query, conn)

print(df)
# Out:
#     MachineID Disponibilidade Desempenho Qualidade   OEE  TotalRegistros
# 0          48            0,72       0,55      0,95  0,38            2058
# 1          15            0,71       0,56      0,95  0,38            2027
# 2          16            0,71       0,57      0,95  0,38            2010
# 3          31            0,70       0,56      0,95  0,38            1933
# 4          27            0,70       0,57      0,95  0,38            1957
# 5          23            0,71       0,56      0,95  0,38            2092
# 6          25            0,71       0,55      0,95  0,37            1998
# 7          49            0,71       0,55      0,95  0,37            1950
# 8           6            0,71       0,55      0,95  0,37            1934
# 9          34            0,69       0,56      0,95  0,37            1948
# 10         42            0,71       0,55      0,95  0,37            2019
# 11         45            0,70       0,55      0,95  0,37            2080
# 12          8            0,70       0,55      0,95  0,37            1967
# 13         21            0,71       0,55      0,95  0,37            2052
# 14         19            0,71       0,55      0,95  0,37            2004
# 15         37            0,71       0,55      0,95  0,37            1964
# 16         26            0,69       0,56      0,95  0,37            2059
# 17         35            0,71       0,55      0,95  0,37            1913
# 18         30            0,71       0,55      0,95  0,37            2074
# 19         41            0,69       0,55      0,95  0,37            2013
# 20         50            0,70       0,55      0,95  0,37            1912
# 21         22            0,69       0,56      0,95  0,37            2031
# 22          2            0,70       0,55      0,95  0,37            2041
# 23         18            0,70       0,55      0,95  0,37            2031
# 24          4            0,71       0,55      0,95  0,37            2004
# 25          1            0,70       0,56      0,95  0,37            1916
# 26         32            0,70       0,56      0,95  0,37            2031
# 27         46            0,72       0,54      0,95  0,37            1912
# 28         29            0,71       0,55      0,95  0,37            2044
# 29         43            0,70       0,56      0,95  0,37            1906
# 30         36            0,71       0,55      0,95  0,37            2085
# 31         12            0,72       0,55      0,95  0,37            1955
# 32         47            0,69       0,55      0,95  0,36            2001
# 33          7            0,70       0,55      0,95  0,36            1965
# 34         38            0,70       0,54      0,95  0,36            2058
# 35         11            0,70       0,55      0,95  0,36            1951
# 36          5            0,70       0,55      0,95  0,36            2043
# 37         13            0,70       0,55      0,95  0,36            2040
# 38         44            0,69       0,56      0,95  0,36            2054
# 39         20            0,69       0,55      0,95  0,36            1970
# 40         39            0,68       0,56      0,95  0,36            1993
# 41         33            0,69       0,55      0,95  0,36            1956
# 42         24            0,69       0,56      0,95  0,36            1984
# 43         40            0,70       0,54      0,95  0,36            2001
# 44         28            0,70       0,55      0,95  0,36            2048
# 45         10            0,69       0,55      0,95  0,36            2022
# 46          3            0,68       0,56      0,95  0,36            2001
# 47         17            0,69       0,54      0,95  0,35            2061
# 48          9            0,69       0,54      0,95  0,35            1991
# 49         14            0,69       0,54      0,95  0,35            1941
# C:\Users\Matt\AppData\Local\Temp\ipykernel_14568\573831378.py:29: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %% [markdown]
# #### Análise Temporal (Tendências)

# %%
query = '''
SELECT
    CAST(t.Timestamp AS DATE) AS Data,
    FORMAT(AVG(p.Production_Speed_units_per_hr), 'N2') AS VelocidadeMediaProducao,
    FORMAT(AVG(p.Error_Rate_Percent), 'N2') AS TaxaErroMedia,
    FORMAT(AVG(q.Quality_Control_Defect_Rate_Percent), 'N2') AS TaxaDefeitoMedia,
    COUNT(*) AS TotalRegistros
FROM FactProduction p
JOIN FactQuality q ON p.MachineKey = q.MachineKey AND p.TimeKey = q.TimeKey
JOIN DimTime t ON p.TimeKey = t.TimeKey
GROUP BY CAST(t.Timestamp AS DATE)
ORDER BY Data;
'''

df = pd.read_sql_query(query, conn)

print(df)
# Out:
#           Data VelocidadeMediaProducao TaxaErroMedia TaxaDefeitoMedia  \
# 0   2024-01-01                  273,83          7,53             5,02
# 1   2024-01-02                  277,94          7,55             5,12
# 2   2024-01-03                  276,06          7,42             5,05
# 3   2024-01-04                  270,64          7,51             4,98
# 4   2024-01-05                  282,10          7,37             5,04
# ..         ...                     ...           ...              ...
# 65  2024-03-06                  276,85          7,72             4,98
# 66  2024-03-07                  280,23          7,38             4,98
# 67  2024-03-08                  276,97          7,56             4,98
# 68  2024-03-09                  279,33          7,55             5,08
# 69  2024-03-10                  270,14          7,39             4,86
#
#     TotalRegistros
# 0             1440
# 1             1440
# 2             1440
# 3             1440
# 4             1440
# ..             ...
# 65            1440
# 66            1440
# 67            1440
# 68            1440
# 69             640
#
# [70 rows x 5 columns]
# C:\Users\Matt\AppData\Local\Temp\ipykernel_14568\414578384.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %% [markdown]
# #### Comparação dia da semana vs fim de semana

# %%
query = '''
SELECT
    CASE 
        WHEN DATEPART(WEEKDAY, t.Timestamp) IN (1, 7) THEN 'Fim de Semana'
        ELSE 'Dia de Semana'
    END AS TipoDia,
    FORMAT(AVG(p.Production_Speed_units_per_hr), 'N2') AS VelocidadeMediaProducao,
    CONCAT(FORMAT(AVG(p.Error_Rate_Percent), 'N2'), '%') AS TaxaErroMedia,
    FORMAT(AVG(p.Power_Consumption_kW), 'N2') AS ConsumoMedioEnergia,
    COUNT(*) AS TotalRegistros
FROM FactProduction p
JOIN DimTime t ON p.TimeKey = t.TimeKey
GROUP BY CASE 
        WHEN DATEPART(WEEKDAY, t.Timestamp) IN (1, 7) THEN 'Fim de Semana'
        ELSE 'Dia de Semana'
    END;
'''

df = pd.read_sql_query(query, conn)

print(df)
# Out:
#          TipoDia VelocidadeMediaProducao TaxaErroMedia ConsumoMedioEnergia  \
# 0  Dia de Semana                  276,29         7,51%                5,75
# 1  Fim de Semana                  274,95         7,48%                5,74
#
#    TotalRegistros
# 0           72000
# 1           28000
# C:\Users\Matt\AppData\Local\Temp\ipykernel_14568\1603125344.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %% [markdown]
# #### Status atual das máquinas (última leitura de cada uma)

# %%
query = '''
WITH UltimasLeituras AS (
    SELECT
        p.MachineKey,
        p.Operation_Mode,
        p.Temperature_C,
        p.Vibration_Hz,
        p.Production_Speed_units_per_hr,
        p.Error_Rate_Percent,
        p.Efficiency_Status,
        t.Timestamp,
        ROW_NUMBER() OVER (PARTITION BY p.MachineKey ORDER BY t.Timestamp DESC) AS RN
    FROM FactProduction p
    JOIN DimTime t ON p.TimeKey = t.TimeKey
)
SELECT
    m.MachineID,
    ul.Operation_Mode AS StatusAtual,
    ul.Temperature_C AS TempAtual,
    ul.Vibration_Hz AS VibracaoAtual,
    ul.Production_Speed_units_per_hr AS VelocidadeProducaoAtual,
    CONCAT(FORMAT(ul.Error_Rate_Percent, 'N2'), '%') AS TaxaErroAtual,
    ul.Efficiency_Status AS StatusEficiencia,
    ul.Timestamp AS UltimaLeitura
FROM UltimasLeituras ul
JOIN DimMachine m ON ul.MachineKey = m.MachineKey
WHERE ul.RN = 1
ORDER BY m.MachineID;
'''

df = pd.read_sql_query(query, conn)

print(df)
# Out:
#     MachineID  StatusAtual  TempAtual  VibracaoAtual  VelocidadeProducaoAtual  \
# 0           1       Active  41.500657       4.075691               428.364469
# 1           2         Idle  68.769712       4.954372               411.605937
# 2           3         Idle  71.143556       1.861171               282.822791
# 3           4       Active  61.238913       0.297255               398.884431
# 4           5       Active  76.527323       1.827437               290.835686
# 5           6       Active  89.658898       4.284868               293.205641
# 6           7         Idle  51.038814       3.853015               419.646252
# 7           8         Idle  76.895243       2.278493               120.726780
# 8           9         Idle  54.569469       3.830994               321.824057
# 9          10       Active  52.800333       2.629977               324.277200
# 10         11       Active  67.812726       2.633789               462.782459
# 11         12  Maintenance  65.279073       4.816808               232.756044
# 12         13       Active  52.558349       2.491930               284.702179
# 13         14         Idle  69.207782       2.145357               177.586249
# 14         15       Active  71.717239       2.761913               363.132817
# 15         16       Active  82.790887       3.856189               222.554297
# 16         17       Active  83.246197       1.431492               130.966330
# 17         18       Active  43.451827       3.557922                63.769083
# 18         19       Active  55.513678       4.456307               324.395227
# 19         20         Idle  52.390980       2.336999               379.559729
# 20         21         Idle  69.568033       3.693716                85.390869
# 21         22       Active  80.437339       0.867544               353.076453
# 22         23         Idle  77.256970       0.377495               466.696532
# 23         24       Active  31.731146       4.963771               175.843882
# 24         25       Active  54.828945       3.158666               387.625034
# 25         26         Idle  61.621900       4.946881               288.149009
# 26         27         Idle  89.470806       4.196672                91.805956
# 27         28         Idle  39.352924       4.178072               418.612780
# 28         29  Maintenance  39.671996       0.861333               419.582972
# 29         30         Idle  56.149537       0.909615               177.625011
# 30         31       Active  39.822510       0.176541               339.481860
# 31         32       Active  34.318703       0.150259               231.469437
# 32         33       Active  82.324051       2.336468               356.561577
# 33         34       Active  79.362641       1.219005               231.915318
# 34         35       Active  53.182693       0.581109                90.169354
# 35         36       Active  59.741843       2.118796                55.244031
# 36         37         Idle  80.497837       3.105462               318.195358
# 37         38       Active  85.377211       2.356036               443.416851
# 38         39  Maintenance  70.515584       1.442156               396.579009
# 39         40       Active  58.126008       4.388378               396.106290
# 40         41       Active  52.394849       4.348519               231.354043
# 41         42       Active  51.943320       4.561880                97.339446
# 42         43       Active  30.954058       0.275522               101.778810
# 43         44         Idle  60.692229       4.960429               236.280348
# 44         45       Active  55.447299       2.176827               195.223260
# 45         46       Active  52.438125       0.762625               164.820026
# 46         47       Active  79.967251       2.283934                65.965864
# 47         48         Idle  47.530914       0.567845               273.756320
# 48         49         Idle  82.123714       2.523885               137.009434
# 49         50       Active  56.776535       2.285540               236.152245
#
#    TaxaErroAtual StatusEficiencia       UltimaLeitura
# 0         10,44%              Low 2024-03-10 09:22:00
# 1         10,32%              Low 2024-03-10 09:13:00
# 2         12,63%              Low 2024-03-10 10:35:00
# 3          8,26%              Low 2024-03-10 09:43:00
# 4          4,51%           Medium 2024-03-10 10:32:00
# 5          0,41%           Medium 2024-03-10 06:55:00
# 6          4,97%           Medium 2024-03-10 08:47:00
# 7          2,28%              Low 2024-03-10 09:00:00
# 8          0,02%           Medium 2024-03-10 10:20:00
# 9          6,32%              Low 2024-03-10 10:37:00
# 10         1,54%             High 2024-03-10 10:19:00
# 11        14,60%              Low 2024-03-10 10:12:00
# 12         8,94%              Low 2024-03-10 10:02:00
# 13         7,58%              Low 2024-03-10 08:56:00
# 14         4,68%           Medium 2024-03-10 10:28:00
# 15         8,84%              Low 2024-03-10 10:25:00
# 16         9,60%              Low 2024-03-10 08:49:00
# 17         2,91%              Low 2024-03-10 10:29:00
# 18         2,16%           Medium 2024-03-10 10:00:00
# 19         7,62%              Low 2024-03-10 10:03:00
# 20         0,51%              Low 2024-03-10 07:45:00
# 21        10,71%              Low 2024-03-10 10:21:00
# 22         2,29%           Medium 2024-03-10 10:36:00
# 23         5,12%              Low 2024-03-10 10:13:00
# 24         1,27%           Medium 2024-03-10 08:33:00
# 25         2,83%           Medium 2024-03-10 10:08:00
# 26         9,33%              Low 2024-03-10 09:36:00
# 27         5,96%              Low 2024-03-10 10:24:00
# 28        14,85%              Low 2024-03-10 10:34:00
# 29        11,50%              Low 2024-03-10 09:19:00
# 30        11,73%              Low 2024-03-10 10:31:00
# 31        14,69%              Low 2024-03-10 10:39:00
# 32         0,21%           Medium 2024-03-10 10:33:00
# 33        13,73%              Low 2024-03-10 10:27:00
# 34        13,36%              Low 2024-03-10 10:09:00
# 35         9,11%              Low 2024-03-10 09:06:00
# 36         5,58%              Low 2024-03-10 08:51:00
# 37        13,96%              Low 2024-03-10 06:13:00
# 38         9,71%              Low 2024-03-10 09:45:00
# 39         6,13%              Low 2024-03-10 10:22:00
# 40         9,98%              Low 2024-03-10 10:10:00
# 41        13,81%              Low 2024-03-10 09:52:00
# 42         2,38%              Low 2024-03-10 10:04:00
# 43         1,14%           Medium 2024-03-10 09:31:00
# 44         5,19%              Low 2024-03-10 10:30:00
# 45        13,54%              Low 2024-03-10 09:20:00
# 46         4,80%              Low 2024-03-10 10:38:00
# 47         1,41%           Medium 2024-03-10 09:55:00
# 48        12,81%              Low 2024-03-10 10:06:00
# 49        13,80%              Low 2024-03-10 07:08:00
# C:\Users\Matt\AppData\Local\Temp\ipykernel_14568\300804319.py:31: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %% [markdown]
# #### Alertas de possíveis problemas

# %%
query = '''
SELECT
    m.MachineID,
    'Temperatura Alta' AS TipoAlerta,
    FORMAT(p.Temperature_C, 'N2') AS Valor,
    t.Timestamp
FROM FactProduction p
JOIN DimMachine m ON p.MachineKey = m.MachineKey
JOIN DimTime t ON p.TimeKey = t.TimeKey
WHERE p.Temperature_C > 85  -- Limite de temperatura
UNION ALL
SELECT
    m.MachineID,
    'Vibração Excessiva' AS TipoAlerta,
    FORMAT(p.Vibration_Hz, 'N2') AS Valor,
    t.Timestamp
FROM FactProduction p
JOIN DimMachine m ON p.MachineKey = m.MachineKey
JOIN DimTime t ON p.TimeKey = t.TimeKey
WHERE p.Vibration_Hz > 4.5  -- Limite de vibração
ORDER BY Timestamp DESC;
'''

df = pd.read_sql_query(query, conn)

print(df)
# Out:
# C:\Users\Matt\AppData\Local\Temp\ipykernel_14568\4103534769.py:24: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)
#        MachineID          TipoAlerta  Valor           Timestamp
# 0             47  Vibração Excessiva   4,84 2024-03-10 10:23:00
# 1             45    Temperatura Alta  86,48 2024-03-10 10:18:00
# 2             45  Vibração Excessiva   4,52 2024-03-10 10:18:00
# 3             24  Vibração Excessiva   4,96 2024-03-10 10:13:00
# 4             12  Vibração Excessiva   4,82 2024-03-10 10:12:00
# ...          ...                 ...    ...                 ...
# 18576         15  Vibração Excessiva   4,71 2024-01-01 00:34:00
# 18577         27  Vibração Excessiva   4,54 2024-01-01 00:30:00
# 18578         24    Temperatura Alta  89,33 2024-01-01 00:18:00
# 18579         40    Temperatura Alta  89,78 2024-01-01 00:13:00
# 18580         39  Vibração Excessiva   4,82 2024-01-01 00:06:00
#
# [18581 rows x 4 columns]

# %% [markdown]
# #### Ranking de máquinas por produtividade

# %%
query = '''
SELECT
    m.MachineID,
    FORMAT(AVG(p.Production_Speed_units_per_hr), 'N2') AS VelocidadeMediaProducao,
    RANK() OVER (ORDER BY AVG(p.Production_Speed_units_per_hr) DESC) AS RankProdutividade,
    CONCAT(FORMAT(AVG(p.Error_Rate_Percent), 'N2'), '%') AS TaxaErroMedia,
    RANK() OVER (ORDER BY AVG(p.Error_Rate_Percent)) AS RankQualidade,
    FORMAT(AVG(p.Power_Consumption_kW / p.Production_Speed_units_per_hr), 'N2') AS EficienciaEnergetica,
    RANK() OVER (ORDER BY AVG(p.Power_Consumption_kW / p.Production_Speed_units_per_hr)) AS RankEficienciaEnergetica
FROM FactProduction p
JOIN DimMachine m ON p.MachineKey = m.MachineKey
WHERE p.Operation_Mode = 'Active'
GROUP BY m.MachineID
ORDER BY RankProdutividade;
'''

df = pd.read_sql_query(query, conn)


print(df)
# Out:
#     MachineID VelocidadeMediaProducao  RankProdutividade TaxaErroMedia  \
# 0          27                  287,43                  1         7,45%
# 1          16                  286,25                  2         7,41%
# 2          34                  282,63                  3         7,53%
# 3          31                  282,34                  4         7,56%
# 4          39                  281,88                  5         7,59%
# 5          15                  281,65                  6         7,40%
# 6          43                  281,43                  7         7,45%
# 7          26                  280,64                  8         7,42%
# 8           3                  280,61                  9         7,62%
# 9          23                  279,71                 10         7,41%
# 10         32                  279,49                 11         7,53%
# 11         24                  279,15                 12         7,40%
# 12         42                  278,93                 13         7,51%
# 13         44                  278,87                 14         7,46%
# 14         45                  278,68                 15         7,42%
# 15          1                  277,77                 16         7,55%
# 16         11                  277,52                 17         7,48%
# 17         37                  277,28                 18         7,31%
# 18         18                  276,39                 19         7,41%
# 19         36                  276,34                 20         7,42%
# 20         47                  276,13                 21         7,65%
# 21         19                  275,70                 22         7,56%
# 22         33                  275,58                 23         7,52%
# 23         25                  275,47                 24         7,69%
# 24         30                  275,41                 25         7,47%
# 25         22                  275,40                 26         7,65%
# 26          2                  275,21                 27         7,62%
# 27         48                  275,16                 28         7,39%
# 28         46                  275,11                 29         7,38%
# 29          7                  274,96                 30         7,33%
# 30         41                  274,91                 31         7,43%
# 31         28                  274,63                 32         7,50%
# 32         50                  274,09                 33         7,28%
# 33          8                  274,08                 34         7,68%
# 34         49                  274,06                 35         7,43%
# 35         20                  273,85                 36         7,36%
# 36         35                  273,77                 37         7,50%
# 37         17                  273,50                 38         7,58%
# 38         14                  273,41                 39         7,59%
# 39          5                  272,34                 40         7,38%
# 40         10                  272,13                 41         7,41%
# 41         21                  271,96                 42         7,47%
# 42         13                  271,94                 43         7,39%
# 43         40                  271,68                 44         7,62%
# 44          6                  271,64                 45         7,54%
# 45         12                  271,34                 46         7,55%
# 46          4                  271,12                 47         7,54%
# 47         38                  271,02                 48         7,65%
# 48          9                  270,33                 49         7,51%
# 49         29                  269,90                 50         7,72%
#
#     RankQualidade EficienciaEnergetica  RankEficienciaEnergetica
# 0              21                 0,03                         1
# 1              12                 0,03                         3
# 2              32                 0,03                        14
# 3              37                 0,03                        15
# 4              41                 0,03                         4
# 5               9                 0,03                        13
# 6              20                 0,03                         7
# 7              16                 0,03                         8
# 8              44                 0,03                         6
# 9              14                 0,03                         2
# 10             31                 0,03                        11
# 11             10                 0,03                         5
# 12             29                 0,03                        27
# 13             22                 0,03                        31
# 14             17                 0,03                        12
# 15             35                 0,03                        22
# 16             25                 0,03                        26
# 17              2                 0,03                        10
# 18             11                 0,03                         9
# 19             15                 0,03                        30
# 20             47                 0,03                        20
# 21             38                 0,03                        41
# 22             30                 0,03                        16
# 23             49                 0,03                        23
# 24             23                 0,03                        24
# 25             45                 0,03                        32
# 26             43                 0,03                        33
# 27              7                 0,03                        40
# 28              5                 0,03                        48
# 29              3                 0,03                        18
# 30             19                 0,03                        37
# 31             27                 0,03                        17
# 32              1                 0,03                        21
# 33             48                 0,03                        47
# 34             18                 0,03                        34
# 35              4                 0,03                        44
# 36             26                 0,03                        46
# 37             39                 0,03                        29
# 38             40                 0,03                        19
# 39              6                 0,03                        50
# 40             13                 0,03                        36
# 41             24                 0,03                        49
# 42              8                 0,03                        25
# 43             42                 0,03                        39
# 44             34                 0,03                        28
# 45             36                 0,03                        35
# 46             33                 0,03                        43
# 47             46                 0,03                        42
# 48             28                 0,03                        45
# 49             50                 0,03                        38
# C:\Users\Matt\AppData\Local\Temp\ipykernel_14568\3570476516.py:18: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %% [markdown]
# #### Máquinas com comportamento Diferente (desvio padrão)

# %%
query = '''
WITH DesviosPorMaquina AS (
    SELECT
        m.MachineID,
        STDEV(p.Production_Speed_units_per_hr) AS DesvioPadraoProducao,
        STDEV(p.Temperature_C) AS DesvioPadraoTemperatura,
        STDEV(p.Vibration_Hz) AS DesvioPadraoVibracao
    FROM FactProduction p
    JOIN DimMachine m ON p.MachineKey = m.MachineKey
    WHERE p.Operation_Mode = 'Active'
    GROUP BY m.MachineID
),

MediasDesvios AS (
    SELECT
        AVG(DesvioPadraoProducao) AS MediaDesvioProducao,
        AVG(DesvioPadraoTemperatura) AS MediaDesvioTemperatura,
        AVG(DesvioPadraoVibracao) AS MediaDesvioVibracao
    FROM DesviosPorMaquina
)

SELECT
    d.MachineID,
    FORMAT(d.DesvioPadraoProducao, 'N2') AS DesvioPadraoProducao,
    FORMAT(d.DesvioPadraoTemperatura, 'N2') AS DesvioPadraoTemperatura,
    FORMAT(d.DesvioPadraoVibracao, 'N2') AS DesvioPadraoVibracao,
    FORMAT(m.MediaDesvioProducao, 'N2') AS MediaDesvioProducao,
    FORMAT(m.MediaDesvioTemperatura, 'N2') AS MediaDesvioTemperatura,
    FORMAT(m.MediaDesvioVibracao, 'N2') AS MediaDesvioVibracao
FROM DesviosPorMaquina d
CROSS JOIN MediasDesvios m
WHERE d.DesvioPadraoProducao > m.MediaDesvioProducao
   OR d.DesvioPadraoTemperatura > m.MediaDesvioTemperatura
   OR d.DesvioPadraoVibracao > m.MediaDesvioVibracao
ORDER BY d.DesvioPadraoProducao DESC;
'''

df = pd.read_sql_query(query, conn)

print(df)
# Out:
#     MachineID DesvioPadraoProducao DesvioPadraoTemperatura  \
# 0           8               133,41                   17,45
# 1          46               132,79                   17,49
# 2          12               132,40                   17,36
# 3           5               132,35                   17,39
# 4          34               132,04                   17,38
# 5          32               131,75                   17,31
# 6          47               131,72                   17,05
# 7          48               131,54                   17,39
# 8          35               131,12                   17,33
# 9          42               131,12                   17,42
# 10         44               131,10                   17,33
# 11         26               131,09                   17,01
# 12         27               130,77                   17,67
# 13          7               130,70                   17,55
# 14         45               130,64                   17,28
# 15         49               130,63                   16,96
# 16          2               130,55                   17,57
# 17         13               130,48                   17,27
# 18         38               130,46                   17,94
# 19         37               130,44                   16,69
# 20         43               130,40                   17,26
# 21         41               130,37                   17,34
# 22         16               130,17                   17,54
# 23         11               130,16                   17,36
# 24          3               130,15                   17,48
# 25         24               130,07                   17,41
# 26         14               129,91                   17,30
# 27         50               129,86                   17,34
# 28         20               129,74                   17,33
# 29         18               129,72                   17,34
# 30         30               129,48                   17,37
# 31         19               129,34                   17,43
# 32         31               129,27                   17,10
# 33         22               129,06                   17,55
# 34         40               129,03                   17,05
# 35          6               128,92                   17,35
# 36         39               128,90                   16,79
# 37         25               128,80                   17,41
# 38         23               128,57                   17,38
# 39          1               128,32                   17,39
# 40         36               128,10                   17,22
# 41          9               127,90                   17,12
# 42         17               127,87                   17,16
#
#    DesvioPadraoVibracao MediaDesvioProducao MediaDesvioTemperatura  \
# 0                  1,44              130,04                  17,30
# 1                  1,41              130,04                  17,30
# 2                  1,40              130,04                  17,30
# 3                  1,40              130,04                  17,30
# 4                  1,42              130,04                  17,30
# 5                  1,41              130,04                  17,30
# 6                  1,42              130,04                  17,30
# 7                  1,38              130,04                  17,30
# 8                  1,41              130,04                  17,30
# 9                  1,45              130,04                  17,30
# 10                 1,40              130,04                  17,30
# 11                 1,43              130,04                  17,30
# 12                 1,41              130,04                  17,30
# 13                 1,41              130,04                  17,30
# 14                 1,40              130,04                  17,30
# 15                 1,41              130,04                  17,30
# 16                 1,41              130,04                  17,30
# 17                 1,41              130,04                  17,30
# 18                 1,41              130,04                  17,30
# 19                 1,43              130,04                  17,30
# 20                 1,39              130,04                  17,30
# 21                 1,44              130,04                  17,30
# 22                 1,41              130,04                  17,30
# 23                 1,38              130,04                  17,30
# 24                 1,43              130,04                  17,30
# 25                 1,41              130,04                  17,30
# 26                 1,44              130,04                  17,30
# 27                 1,41              130,04                  17,30
# 28                 1,42              130,04                  17,30
# 29                 1,41              130,04                  17,30
# 30                 1,39              130,04                  17,30
# 31                 1,41              130,04                  17,30
# 32                 1,42              130,04                  17,30
# 33                 1,40              130,04                  17,30
# 34                 1,43              130,04                  17,30
# 35                 1,43              130,04                  17,30
# 36                 1,43              130,04                  17,30
# 37                 1,41              130,04                  17,30
# 38                 1,42              130,04                  17,30
# 39                 1,40              130,04                  17,30
# 40                 1,43              130,04                  17,30
# 41                 1,42              130,04                  17,30
# 42                 1,45              130,04                  17,30
#
#    MediaDesvioVibracao
# 0                 1,41
# 1                 1,41
# 2                 1,41
# 3                 1,41
# 4                 1,41
# 5                 1,41
# 6                 1,41
# 7                 1,41
# 8                 1,41
# 9                 1,41
# 10                1,41
# 11                1,41
# 12                1,41
# 13                1,41
# 14                1,41
# 15                1,41
# 16                1,41
# 17                1,41
# 18                1,41
# 19                1,41
# 20                1,41
# 21                1,41
# 22                1,41
# 23                1,41
# 24                1,41
# 25                1,41
# 26                1,41
# 27                1,41
# 28                1,41
# 29                1,41
# 30                1,41
# 31                1,41
# 32                1,41
# 33                1,41
# 34                1,41
# 35                1,41
# 36                1,41
# 37                1,41
# 38                1,41
# 39                1,41
# 40                1,41
# 41                1,41
# 42                1,41
# C:\Users\Matt\AppData\Local\Temp\ipykernel_14568\1857946295.py:38: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)
